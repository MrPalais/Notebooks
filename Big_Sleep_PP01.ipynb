# %% [markdown]
# <a href="https://colab.research.google.com/github/MrPalais/Notebooks/blob/main/Big_Sleep_PP01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://github.com/lucidrains/big-sleep
#
# version complète :
# https://colab.research.google.com/drive/1zVHK4t3nXQTsu5AskOOOf3Mc9TnhltUO?usp=sharing

# %%
# !pip uninstall folium -y -q
# !pip install big-sleep --upgrade -q

# %%
from tqdm.notebook import trange
from IPython.display import Image, display

from big_sleep import Imagine

TEXT = 'photo of a kitchen' #@param {type:"string"}
SAVE_EVERY = 1 #@param {type:"number"}
SAVE_PROGRESS = True #@param {type:"boolean"}
LEARNING_RATE = 0.07 #@param {type:"number"}
ITERATIONS = 1050 #@param {type:"number"}
SEED = 38 #@param {type: "number"}

dir='/content/OUT/'
# %cd {dir}
# !echo "LR={LEARNING_RATE} SEED={SEED}" >params.txt

model = Imagine(
    text = TEXT,
    save_every = SAVE_EVERY,
    lr = LEARNING_RATE,
    iterations = ITERATIONS,
    save_progress = SAVE_PROGRESS,
    seed = SEED
)

for epoch in trange(20, desc = 'epochs'):
    for i in trange(1000, desc = 'iteration'):
        model.train_step(epoch, i)

        if i == 0 or i % model.save_every != 0:
            continue

        filename = TEXT.replace(' ', '_')
        image = Image(f'./{filename}.png')
        display(image)
# Out:
# image updated at "./photo_of_a_kitchen.png"
# image updated at "./photo_of_a_kitchen.png"
# image updated at "./photo_of_a_kitchen.png"

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
z='/content/images.zip'
# !rm -f {z}
# !zip {z} /content/*.png >/dev/null
# !ls -l {z}
# !curl --upload-file {z} https://oshi.at/images.zip
# Out:
# -rw-r--r-- 1 root root 65228633 Apr 21 11:17 /content/images.zip
#
# https://oshi.at/a/767b04f5be71cbe04c5bd569e62a30e146c9ab24 [Admin]
# https://oshi.at/jzoY [Download]
# http://5ety7tpkim5me6eszuwcje7bmy25pbtrjtue7zkqqgziljwqy3rrikqd.onion/jzoY [Tor download]

# %%
# !rm -f /content/*.png
