# %% [markdown]
# <a href="https://colab.research.google.com/github/MrPalais/Notebooks/blob/main/NNST.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://github.com/nkolkin13/NeuralNeighborStyleTransfer

# %%
# !git -q clone https://github.com/nkolkin13/NeuralNeighborStyleTransfer
# !pip -q install imageio==2.8.0 numpy==1.18.1

# %%
# !python /content/NeuralNeighborStyleTransfer/styleTransfer.py -h
# Out:
# usage: styleTransfer.py [-h] --content_path CONTENT_PATH --style_path
#                         STYLE_PATH --output_path OUTPUT_PATH [--high_res]
#                         [--cpu] [--no_flip] [--content_loss] [--dont_colorize]
#                         [--alpha ALPHA]
#
# optional arguments:
#   -h, --help            show this help message and exit
#   --content_path CONTENT_PATH
#   --style_path STYLE_PATH
#   --output_path OUTPUT_PATH
#   --high_res
#   --cpu
#   --no_flip
#   --content_loss
#   --dont_colorize
#   --alpha ALPHA

# %%
# %cd /content/NeuralNeighborStyleTransfer
# !python styleTransfer.py --dont_colorize --high_res --content_path /content/NeuralNeighborStyleTransfer/inputs/content/C8.png --style_path /content/NeuralNeighborStyleTransfer/inputs/style/S3.jpg --output_path /content/out2.jpg
# Out:
# /content/NeuralNeighborStyleTransfer
# -(0, 64)-
# -(1, 128)-
# -(2, 256)-
# -(3, 512)-
# -(4, 1024)-
# tcmalloc: large alloc 2686451712 bytes == 0x9a500000 @  0x7f6f7bc74b6b 0x7f6f7bc94379 0x7f6ebaba250e 0x7f6ebab947c2 0x7f6ef4b051a7 0x7f6ef4b05449 0x7f6ef4b054a6 0x7f6ef4fd99f8 0x7f6ef56c6c0f 0x7f6ef5488656 0x7f6ef56ac466 0x7f6ef54c6367 0x7f6ef4fd6dad 0x7f6ef57c88ea 0x7f6ef528f5f9 0x7f6ef56ada47 0x7f6ef528f5f9 0x7f6ef62e14c6 0x7f6ef62e1a0d 0x7f6ef52fcf4a 0x7f6ef4fd2092 0x7f6ef585f280 0x7f6ef53ef501 0x7f6f6ff6c60e 0x7f6f6ff6db0e 0x59b1b0 0x515655 0x549576 0x593fce 0x548ae9 0x5127f1
# ...

# %%
from IPython.display import Image
Image('/content/out2.jpg')
