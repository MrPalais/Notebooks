# %% [markdown]
# <a href="https://colab.research.google.com/github/MrPalais/Notebooks/blob/main/NNST2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Transfert de style NNST
#
# assez long pour la haute résolution (1024) mais précis dans les détails
#
# demande bcp de RAM : réduire la taille de l'image du style au besoin.
#
# https://github.com/nkolkin13/NeuralNeighborStyleTransfer

# %%
# !git -q clone https://github.com/nkolkin13/NeuralNeighborStyleTransfer
# !pip -q install imageio==2.8.0 numpy==1.18.1

# %%
# !python /content/NeuralNeighborStyleTransfer/styleTransfer.py -h
# Out:
# usage: styleTransfer.py [-h] --content_path CONTENT_PATH --style_path
#                         STYLE_PATH --output_path OUTPUT_PATH [--high_res]
#                         [--cpu] [--no_flip] [--content_loss] [--dont_colorize]
#                         [--alpha ALPHA]
#
# optional arguments:
#   -h, --help            show this help message and exit
#   --content_path CONTENT_PATH
#   --style_path STYLE_PATH
#   --output_path OUTPUT_PATH
#   --high_res
#   --cpu
#   --no_flip
#   --content_loss
#   --dont_colorize
#   --alpha ALPHA

# %%
# Out:
# /content/NeuralNeighborStyleTransfer
# -(0, 64)-
# -(1, 128)-
# -(2, 256)-
# -(3, 512)-
# -(4, 1024)-
# tcmalloc: large alloc 2146959360 bytes == 0x91910000 @  0x7fdaff501b6b 0x7fdaff521379 0x7fda3e42f50e 0x7fda3e4217c2 0x7fda783921a7 0x7fda78392449 0x7fda783924a6 0x7fda788669f8 0x7fda78f53c0f 0x7fda78d15656 0x7fda78f39466 0x7fda78d53367 0x7fda78863dad 0x7fda790558ea 0x7fda78b1c5f9 0x7fda78f3aa47 0x7fda78b1c5f9 0x7fda79b6e4c6 0x7fda79b6ea0d 0x7fda78b89f4a 0x7fda7885f092 0x7fda790ec280 0x7fda78c7c501 0x7fdaf37f960e 0x7fdaf37fab0e 0x59b1b0 0x515655 0x549576 0x593fce 0x548ae9 0x5127f1
# ...

# %%
# %cd /content/NeuralNeighborStyleTransfer
# !python styleTransfer.py --dont_colorize --high_res --content_path /content/NeuralNeighborStyleTransfer/inputs/content/C8.png --style_path /content/NeuralNeighborStyleTransfer/inputs/style/S1.jpg --output_path /content/out3.jpg
from IPython.display import Image
Image('/content/out3.jpg')

# %%
# %cd /content/NeuralNeighborStyleTransfer
# !python styleTransfer.py --dont_colorize --high_res --content_path /content/NeuralNeighborStyleTransfer/inputs/content/C8.png --style_path /content/NeuralNeighborStyleTransfer/inputs/style/S2.jpg --output_path /content/out5.jpg
from IPython.display import Image
Image('/content/out5.jpg')
# Out:
# /content/NeuralNeighborStyleTransfer
# -(0, 64)-
# -(1, 128)-
# -(2, 256)-
# -(3, 512)-
# -(4, 1024)-
# tcmalloc: large alloc 2224029696 bytes == 0x9354e000 @  0x7fc5c836bb6b 0x7fc5c838b379 0x7fc50729950e 0x7fc50728b7c2 0x7fc5411fc1a7 0x7fc5411fc449 0x7fc5411fc4a6 0x7fc5416d09f8 0x7fc541dbdc0f 0x7fc541b7f656 0x7fc541da3466 0x7fc541bbd367 0x7fc5416cddad 0x7fc541ebf8ea 0x7fc5419865f9 0x7fc541da4a47 0x7fc5419865f9 0x7fc5429d84c6 0x7fc5429d8a0d 0x7fc5419f3f4a 0x7fc5416c9092 0x7fc541f56280 0x7fc541ae6501 0x7fc5bc66360e 0x7fc5bc664b0e 0x59b1b0 0x515655 0x549576 0x593fce 0x548ae9 0x5127f1
# ...

# %%
from IPython.display import Image
Image('/content/out2.jpg')
